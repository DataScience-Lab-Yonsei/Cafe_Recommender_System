# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
basedf = pd.read_csv('저장경로/naver_processed.csv')
# 크롤링해온 매장들 중 카페가 아닌 것들을 모두 제거한 파일.

# %%
basedf.columns
# Out:
# Index(['Unnamed: 0', 'name', 'search_name', 'address', 'road_address',
#        'near_station', 'station_distance', 'total_review', '"커피가 맛있어요"',
#        '"친절해요"', '"음료가 맛있어요"', '"디저트가 맛있어요"', '"매장이 청결해요"', '"대화하기 좋아요"',
#        '"집중하기 좋아요"', '"인테리어가 멋져요"', '"좌석이 편해요"', '"화장실이 깨끗해요"',
#        '"특별한 메뉴가 있어요"', '"가성비가 좋아요"', '"뷰가 좋아요"', '"주차하기 편해요"', '"사진이 잘 나와요"',
#        'cafe'],
#       dtype='object')

# %%
naver = pd.read_csv('/data/naver_data/naver_review.csv')

# %%
naver.columns
# Out:
# Index(['search_name', 'address', 'road_address', 'near_station',
#        'station_distance', 'total_review', '"커피가 맛있어요"', '"친절해요"',
#        '"음료가 맛있어요"', '"디저트가 맛있어요"', '"매장이 청결해요"', '"대화하기 좋아요"', '"집중하기 좋아요"',
#        '"인테리어가 멋져요"', '"좌석이 편해요"', '"화장실이 깨끗해요"', '"특별한 메뉴가 있어요"',
#        '"가성비가 좋아요"', '"뷰가 좋아요"', '"주차하기 편해요"', '"사진이 잘 나와요"'],
#       dtype='object')

# %%
basedf = basedf[['search_name', 'address', 'road_address',
       'near_station', 'station_distance', 'total_review', '"커피가 맛있어요"',
       '"친절해요"', '"음료가 맛있어요"', '"디저트가 맛있어요"', '"매장이 청결해요"', '"대화하기 좋아요"',
       '"집중하기 좋아요"', '"인테리어가 멋져요"', '"좌석이 편해요"', '"화장실이 깨끗해요"',
       '"특별한 메뉴가 있어요"', '"가성비가 좋아요"', '"뷰가 좋아요"', '"주차하기 편해요"', '"사진이 잘 나와요"',
       'cafe']]

# %%
print(len(basedf))
print(len(naver))
# Out:
# 7960
# 7661

# %%
basenew=pd.DataFrame()
for i in range(len(naver)):
  plz = basedf[basedf['search_name']==naver['search_name'][i]]
  basenew = basenew.append(plz[plz['address']==naver['address'][i]].head(1))
  print(len(basenew))

# %%
basenew.

# %%
basenew

# %%
naver['search_name'].nunique()
# Out:
# 7569

# %%
plzz = naver.merge(basenew, how='inner',on=['search_name', 'address', 'road_address',
       'near_station', 'station_distance', 'total_review', '"커피가 맛있어요"',
       '"친절해요"', '"음료가 맛있어요"', '"디저트가 맛있어요"', '"매장이 청결해요"', '"대화하기 좋아요"',
       '"집중하기 좋아요"', '"인테리어가 멋져요"', '"좌석이 편해요"', '"화장실이 깨끗해요"',
       '"특별한 메뉴가 있어요"', '"가성비가 좋아요"', '"뷰가 좋아요"', '"주차하기 편해요"', '"사진이 잘 나와요"'])
plzz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7661 entries, 0 to 7660
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   search_name       7661 non-null   object
#  1   address           7661 non-null   object
#  2   road_address      6878 non-null   object
#  3   near_station      6878 non-null   object
#  4   station_distance  6878 non-null   float64
#  5   total_review      7661 non-null   int64
#  6   "커피가 맛있어요"        7661 non-null   float64
#  7   "친절해요"            7661 non-null   float64
#  8   "음료가 맛있어요"        7661 non-null   float64
#  9   "디저트가 맛있어요"       7661 non-null   float64
#  10  "매장이 청결해요"        7661 non-null   float64
#  11  "대화하기 좋아요"        7661 non-null   float64
#  12  "집중하기 좋아요"        7661 non-null   float64
#  13  "인테리어가 멋져요"       7661 non-null   float64
#  14  "좌석이 편해요"         7661 non-null   float64
#  15  "화장실이 깨끗해요"       7661 non-null   float64
# ...

# %%
plzz[plzz['search_name']=='카페코브']
# Out:
#      search_name address             road_address near_station  \
# 2480        카페코브     석촌동  서울 송파구 가락로15길 9 1층 카페코브        89석촌역
# 2481        카페코브     석촌동  서울 송파구 가락로15길 9 1층 카페코브        89석촌역
#
#       station_distance  total_review  "커피가 맛있어요"  "친절해요"  "음료가 맛있어요"  \
# 2480             518.0            41        24.0    18.0        13.0
# 2481             518.0            41        24.0    18.0        13.0
#
#       "디저트가 맛있어요"  ...  "집중하기 좋아요"  "인테리어가 멋져요"  "좌석이 편해요"  "화장실이 깨끗해요"  \
# 2480         27.0  ...         7.0         13.0        0.0          3.0
# 2481         27.0  ...         7.0         13.0        0.0          3.0
#
#       "특별한 메뉴가 있어요"  "가성비가 좋아요"  "뷰가 좋아요"  "주차하기 편해요"  "사진이 잘 나와요"  \
# 2480            6.0         2.0       2.0         1.0          6.0
# 2481            6.0         2.0       2.0         1.0          6.0
#
#               cafe
# 2480  cafecobh 석촌동
# 2481  cafecobh 석촌동
#
# [2 rows x 22 columns]

# %%
naver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7661 entries, 0 to 7660
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   search_name       7661 non-null   object
#  1   address           7661 non-null   object
#  2   road_address      6877 non-null   object
#  3   near_station      6877 non-null   object
#  4   station_distance  6877 non-null   float64
#  5   total_review      7661 non-null   int64
#  6   "커피가 맛있어요"        7661 non-null   float64
#  7   "친절해요"            7661 non-null   float64
#  8   "음료가 맛있어요"        7661 non-null   float64
#  9   "디저트가 맛있어요"       7661 non-null   float64
#  10  "매장이 청결해요"        7661 non-null   float64
#  11  "대화하기 좋아요"        7661 non-null   float64
#  12  "집중하기 좋아요"        7661 non-null   float64
#  13  "인테리어가 멋져요"       7661 non-null   float64
#  14  "좌석이 편해요"         7661 non-null   float64
#  15  "화장실이 깨끗해요"       7661 non-null   float64
# ...

# %%
naver.head()
# Out:
#   search_name address                road_address  near_station  \
# 0        버블베어     방화동  서울 강서구 금낭화로 167 방화8단지개화아파트          5방화역
# 1   커피빈 낙성대역점     봉천동      서울 관악구 남부순환로 1909 1,2층         2낙성대역
# 2  노란꼬무줄 선릉본점     대치동   서울 강남구 선릉로 424 1층5호 노란꼬무줄      2수인분당선릉역
# 3         커피랩     서교동           서울 마포구 와우산로29길 14  2공항경의중앙홍대입구역
# 4  커핀그루나루 신천점     잠실동            서울 송파구 올림픽로12길 8        2잠실새내역
#
#    station_distance  total_review  "커피가 맛있어요"  "친절해요"  "음료가 맛있어요"  \
# 0             427.0            18         7.0     5.0         5.0
# 1             119.0           284         7.0    56.0        74.0
# 2             157.0           134        40.0    14.0        61.0
# 3             324.0           100        76.0    23.0        13.0
# 4             228.0           140        64.0    14.0        31.0
#
#    "디저트가 맛있어요"  ...  "대화하기 좋아요"  "집중하기 좋아요"  "인테리어가 멋져요"  "좌석이 편해요"  \
# 0          6.0  ...         0.0         0.0          0.0        1.0
# ...

# %%
naver.tail()
# Out:
#        search_name address           road_address near_station  \
# 7656    커피나무 보라매역점     신길동      서울 영등포구 여의대방로 135      7신림보라매역
# 7657       스노잉 합정점     합정동          서울 마포구 성지길 22        26합정역
# 7658  이디야커피 논골사거리점   금호동1가          서울 성동구 난계로 35         5행당역
# 7659         퍼블릭맨션      목동         서울 양천구 등촌로 154         9등촌역
# 7660  이디야커피 굽은다리역점     천호동  서울 강동구 양재대로 1543 진주빌딩       5굽은다리역
#
#       station_distance  total_review  "커피가 맛있어요"  "친절해요"  "음료가 맛있어요"  \
# 7656              44.0           219         0.0    40.0        38.0
# 7657             140.0            48        21.0    17.0        11.0
# 7658             395.0           189         1.0    46.0        38.0
# 7659             825.0            27        17.0    13.0         9.0
# 7660             227.0            65        28.0    20.0        12.0
#
#       "디저트가 맛있어요"  ...  "대화하기 좋아요"  "집중하기 좋아요"  "인테리어가 멋져요"  "좌석이 편해요"  \
# 7656         67.0  ...        40.0         8.0         16.0       28.0
# ...

# %%
plzz.tail()
# Out:
#        search_name address           road_address near_station  \
# 7656    커피나무 보라매역점     신길동      서울 영등포구 여의대방로 135      7신림보라매역
# 7657       스노잉 합정점     합정동          서울 마포구 성지길 22        26합정역
# 7658  이디야커피 논골사거리점   금호동1가          서울 성동구 난계로 35         5행당역
# 7659         퍼블릭맨션      목동         서울 양천구 등촌로 154         9등촌역
# 7660  이디야커피 굽은다리역점     천호동  서울 강동구 양재대로 1543 진주빌딩       5굽은다리역
#
#       station_distance  total_review  "커피가 맛있어요"  "친절해요"  "음료가 맛있어요"  \
# 7656              44.0           219         0.0    40.0        38.0
# 7657             140.0            48        21.0    17.0        11.0
# 7658             395.0           189         1.0    46.0        38.0
# 7659             825.0            27        17.0    13.0         9.0
# 7660             227.0            65        28.0    20.0        12.0
#
#       "디저트가 맛있어요"  ...  "집중하기 좋아요"  "인테리어가 멋져요"  "좌석이 편해요"  "화장실이 깨끗해요"  \
# 7656         67.0  ...         8.0         16.0       28.0          8.0
# ...

# %%
plzz.head()
# Out:
#   search_name address                road_address  near_station  \
# 0        버블베어     방화동  서울 강서구 금낭화로 167 방화8단지개화아파트          5방화역
# 1   커피빈 낙성대역점     봉천동      서울 관악구 남부순환로 1909 1,2층         2낙성대역
# 2  노란꼬무줄 선릉본점     대치동   서울 강남구 선릉로 424 1층5호 노란꼬무줄      2수인분당선릉역
# 3         커피랩     서교동           서울 마포구 와우산로29길 14  2공항경의중앙홍대입구역
# 4  커핀그루나루 신천점     잠실동            서울 송파구 올림픽로12길 8        2잠실새내역
#
#    station_distance  total_review  "커피가 맛있어요"  "친절해요"  "음료가 맛있어요"  \
# 0             427.0            18         7.0     5.0         5.0
# 1             119.0           284         7.0    56.0        74.0
# 2             157.0           134        40.0    14.0        61.0
# 3             324.0           100        76.0    23.0        13.0
# 4             228.0           140        64.0    14.0        31.0
#
#    "디저트가 맛있어요"  ...  "집중하기 좋아요"  "인테리어가 멋져요"  "좌석이 편해요"  "화장실이 깨끗해요"  \
# 0          6.0  ...         0.0          0.0        1.0          2.0
# ...

# %%
plzz.to_csv('/data/naver_data/naver_review_name.csv',index=False)
